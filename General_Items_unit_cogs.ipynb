# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumi7/TFNotebooks/blob/master/General_Items_unit_cogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df=pd.read_csv("drive/My Drive/MERGED_FINAL_DATASET.csv")

# %%
df
# Out:
#        Unnamed: 0        date  ...  monthly_avg_cloudcover monthly_avg_humidity
# 0               0  2018-01-01  ...                       2                82.81
# 1               1  2018-01-01  ...                       2                82.81
# 2               2  2018-01-01  ...                       2                82.81
# 3               3  2018-01-01  ...                       2                82.81
# 4               4  2018-01-01  ...                       2                82.81
# ...           ...         ...  ...                     ...                  ...
# 23175       23175  2018-01-12  ...                       3                88.58
# 23176       23176  2018-01-12  ...                       3                88.58
# 23177       23177  2018-01-12  ...                       3                88.58
# 23178       23178  2018-01-12  ...                       3                88.58
# 23179       23179  2018-01-12  ...                       3                88.58
#
# ...

# %%
df=df.drop(['Unnamed: 0',	'date', 'ishol/week',	'quantity','monthly_Avgtemp',	'monthly_avg_FeelsLikeC',	'monthly_avg_HeatIndexC',	'monthly_avg_cloudcover',	'monthly_avg_humidity'],axis=1)

# %% [markdown]
# So we create a dictionary to store the separated datasets with key as name of each group

# %%
d = {}

for frame, data in df.groupby('group'):
    d[frame] = data

# %%
print(d)
# Out:
# {'ALCOHOL':          group                                      name  unit_cogs
# 12     ALCOHOL            PIWO BOJAN  WIELKOP.0_5 L B/ZW       2.50
# 13     ALCOHOL            PIWO BOJAN FAJRANT 0_5 L B/ZWR       1.61
# 14     ALCOHOL              PIWO BOJAN KOKOS 0_5 L B/ZWR       3.02
# 15     ALCOHOL          PIWO BOJAN STRAZACKIE 0_5 L B/ZW       2.50
# 16     ALCOHOL           PIWO BOJAN SZWEJK 0_5 L B/ZWROT       2.37
# ...        ...                                       ...        ...
# 23175  ALCOHOL            WINO TOTINO CHERRY VERMOUTH 1L       9.80
# 23176  ALCOHOL       WINO WALDWEIN JEZYNA 0_75 L SLODKIE       7.60
# 23177  ALCOHOL       WINO WALDWEIN MALINA 0_75 L SLODKIE       7.60
# 23178  ALCOHOL  WODKA DRINK SOBIESKI 025ML CRANBERRY4.4%       2.89
# 23179  ALCOHOL      WODKA DRINK SOBIESKI KAMIKAZE.250 ML       2.89
#
# [1807 rows x 3 columns], 'BREAD':        group                                name  unit_cogs
# ...

# %%
for key in d.keys():
  d[key]=d[key].drop(['group'],axis=1)

# %%
print(d['SWEETS'])
# Out:
#                                    name  unit_cogs
# 1495     AMELIA PIANKA 380 G SMIET.CZEK   4.180000
# 1496                ANDRUTY   FURMANIAK   0.699381
# 1497                      ANIMALS MODEL   5.680000
# 1498        BATON 7DAYS KAKAO W POLEWIE   0.550000
# 1499                   BATON BOUNTY 57G   1.490000
# ...                                 ...        ...
# 22994           ZELKI NIM 2 MLEKODUSZKI   1.870000
# 22995                 ZELKI NIM 2 SHOKI   2.100000
# 22996            ZELKI NIM 2SOKKI  90 G   1.860000
# 22997      ZELKI NIMM 2 JOGURTOWE 100 G   1.860000
# 22998  ZURAWINA W CZEKOLADZIE 70 G EURO   1.830000
#
# [2298 rows x 2 columns]

# %%
s=d['SWEETS'].drop_duplicates()
print(s)
# Out:
#                                  name  unit_cogs
# 1495   AMELIA PIANKA 380 G SMIET.CZEK   4.180000
# 1496              ANDRUTY   FURMANIAK   0.699381
# 1497                    ANIMALS MODEL   5.680000
# 1498      BATON 7DAYS KAKAO W POLEWIE   0.550000
# 1499                 BATON BOUNTY 57G   1.490000
# ...                               ...        ...
# 22993       ZELKI NIM 2 HAPPIES 130 G   2.080000
# 22994         ZELKI NIM 2 MLEKODUSZKI   1.870000
# 22995               ZELKI NIM 2 SHOKI   2.100000
# 22996          ZELKI NIM 2SOKKI  90 G   1.860000
# 22997    ZELKI NIMM 2 JOGURTOWE 100 G   1.860000
#
# [1176 rows x 2 columns]

# %% [markdown]
# Just to be sure XD

# %%
len(d)
# Out:
# 22

# %%
d['SPICES']
# Out:
#                                        name  unit_cogs
# 1428                   APEPETITA GYROS 30 G     1.0000
# 1429                  APETTITA CYNAMON 20 G     0.7900
# 1430            APPETITA GALKA MUSZKATOLOWA     0.9900
# 1431                 APPETITA IMBIR MIELONY     0.9900
# 1432     APPETITA PRZYPRAWA DO GULASZU 20 G     0.9700
# ...                                     ...        ...
# 22812               WIN ZIARENKA SMAKU 120G     1.6600
# 22813                WIN ZIARENKA SMAKU 75G     1.5325
# 22814                WIN ZUPA GRZYBOWA 48 G     1.1800
# 22815       ZUPA BLYSKAWICZNA WOLOWINA 60 G     0.3000
# 22816  ZUPA BLYSKAWICZNA Z MAK KURCZAK 60 G     0.3000
#
# [775 rows x 2 columns]
#                                        name  unit_cogs
# 1428                   APEPETITA GYROS 30 G     1.0000
# 1429                  APETTITA CYNAMON 20 G     0.7900
# 1430            APPETITA GALKA MUSZKATOLOWA     0.9900
# 1431                 APPETITA IMBIR MIELONY     0.9900
# ...

# %%
d['ALCOHOL']
# Out:
#                                            name  unit_cogs
# 12               PIWO BOJAN  WIELKOP.0_5 L B/ZW       2.50
# 13               PIWO BOJAN FAJRANT 0_5 L B/ZWR       1.61
# 14                 PIWO BOJAN KOKOS 0_5 L B/ZWR       3.02
# 15             PIWO BOJAN STRAZACKIE 0_5 L B/ZW       2.50
# 16              PIWO BOJAN SZWEJK 0_5 L B/ZWROT       2.37
# ...                                         ...        ...
# 23175            WINO TOTINO CHERRY VERMOUTH 1L       9.80
# 23176       WINO WALDWEIN JEZYNA 0_75 L SLODKIE       7.60
# 23177       WINO WALDWEIN MALINA 0_75 L SLODKIE       7.60
# 23178  WODKA DRINK SOBIESKI 025ML CRANBERRY4.4%       2.89
# 23179      WODKA DRINK SOBIESKI KAMIKAZE.250 ML       2.89
#
# [1807 rows x 2 columns]

# %% [markdown]
# Storing all the dataframes as csv files in a folder of datasets

# %%
for key in d:
  name='drive/My Drive/GROUP_OF_ITEMS_FINAL/'+key+".csv"
  d[key].to_csv(name)
