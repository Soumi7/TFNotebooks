# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My Drive/C3D-keras
# Out:
# /content/drive/My Drive/C3D-keras

# %%
# !ls
# Out:
# callbacks.py	   models.py	schedules.py	UCF101Autism	  video_demo.py
# check_empty.py	   __pycache__	test_list.txt	ucf101imgs	  videos
# LICENSE		   README.md	train_c3d.py	ucfTrainTestlist
# make_label_txt.py  results	train_list.txt	video2img.py

# %%
# !python video2img.py
# Out:
# ./ucf101imgs/HeadBanging/v_HeadBanging_g01_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g02_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g03_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g04_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g05_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g06_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g07_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g08_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g09_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g10_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g12_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g13_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g14_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g15_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g16_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g17_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g18_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g19_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g20_c01/
# ./ucf101imgs/HeadBanging/v_HeadBanging_g21_c01/
# ...

# %%
# !python make_label_txt.py
# Out:
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g07_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g08_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g09_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g10_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g11_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g12_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g13_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g14_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g15_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g16_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g17_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g18_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g19_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g20_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g21_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g22_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g23_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g24_c01
# ./ucf101imgs/ArmFlapping/v_ArmFlapping_g25_c01
# ./ucf101imgs/Basketball/v_Basketball_g03_c01
# ...

# %%
# !python models.py
# Out:
# Using TensorFlow backend.
# 2020-07-13 13:40:40.547733: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1

# %%
# !python train_c3d.py
# Out:
# Using TensorFlow backend.
# 2020-07-13 13:40:45.702717: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-07-13 13:40:47.405220: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-13 13:40:47.443212: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-13 13:40:47.443776: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1561] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# 2020-07-13 13:40:47.443819: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# ...
