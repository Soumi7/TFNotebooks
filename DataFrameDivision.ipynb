# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumi7/TFNotebooks/blob/master/DataFrameDivision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
df=pd.read_csv("drive/My Drive/MERGED_FINAL_DATASET.csv")

# %%
df
# Out:
#        Unnamed: 0        date  ...  monthly_avg_cloudcover monthly_avg_humidity
# 0               0  2018-01-01  ...                       2                82.81
# 1               1  2018-01-01  ...                       2                82.81
# 2               2  2018-01-01  ...                       2                82.81
# 3               3  2018-01-01  ...                       2                82.81
# 4               4  2018-01-01  ...                       2                82.81
# ...           ...         ...  ...                     ...                  ...
# 23175       23175  2018-01-12  ...                       3                88.58
# 23176       23176  2018-01-12  ...                       3                88.58
# 23177       23177  2018-01-12  ...                       3                88.58
# 23178       23178  2018-01-12  ...                       3                88.58
# 23179       23179  2018-01-12  ...                       3                88.58
#
# ...

# %% [markdown]
# So we create a dictionary to store the separated datasets with key as name of each group

# %%
d = {}

for frame, data in df.groupby('group'):
    d[frame] = data

# %%
print(d)
# Out:
# {'ALCOHOL':        Unnamed: 0        date  ...  monthly_avg_cloudcover monthly_avg_humidity
# 12             12  2018-01-01  ...                       2                82.81
# 13             13  2018-01-01  ...                       2                82.81
# 14             14  2018-01-01  ...                       2                82.81
# 15             15  2018-01-01  ...                       2                82.81
# 16             16  2018-01-01  ...                       2                82.81
# ...           ...         ...  ...                     ...                  ...
# 23175       23175  2018-01-12  ...                       3                88.58
# 23176       23176  2018-01-12  ...                       3                88.58
# 23177       23177  2018-01-12  ...                       3                88.58
# 23178       23178  2018-01-12  ...                       3                88.58
# 23179       23179  2018-01-12  ...                       3                88.58
#
# ...

# %% [markdown]
# Just to be sure XD

# %%
len(d)
# Out:
# 22

# %%
d['SPICES']
# Out:
#        Unnamed: 0        date  ...  monthly_avg_cloudcover monthly_avg_humidity
# 1428         1428  2018-01-01  ...                       2                82.81
# 1429         1429  2018-01-01  ...                       2                82.81
# 1430         1430  2018-01-01  ...                       2                82.81
# 1431         1431  2018-01-01  ...                       2                82.81
# 1432         1432  2018-01-01  ...                       2                82.81
# ...           ...         ...  ...                     ...                  ...
# 22812       22812  2018-01-12  ...                       3                88.58
# 22813       22813  2018-01-12  ...                       3                88.58
# 22814       22814  2018-01-12  ...                       3                88.58
# 22815       22815  2018-01-12  ...                       3                88.58
# 22816       22816  2018-01-12  ...                       3                88.58
#
# ...

# %%
d['ALCOHOL']
# Out:
#        Unnamed: 0        date  ...  monthly_avg_cloudcover monthly_avg_humidity
# 12             12  2018-01-01  ...                       2                82.81
# 13             13  2018-01-01  ...                       2                82.81
# 14             14  2018-01-01  ...                       2                82.81
# 15             15  2018-01-01  ...                       2                82.81
# 16             16  2018-01-01  ...                       2                82.81
# ...           ...         ...  ...                     ...                  ...
# 23175       23175  2018-01-12  ...                       3                88.58
# 23176       23176  2018-01-12  ...                       3                88.58
# 23177       23177  2018-01-12  ...                       3                88.58
# 23178       23178  2018-01-12  ...                       3                88.58
# 23179       23179  2018-01-12  ...                       3                88.58
#
# ...

# %% [markdown]
# Storing all the dataframes as csv files in a folder of datasets

# %%
for key in d:
  name='drive/My Drive/GROUP_OF_DATASETS/'+key+".csv"
  d[key].to_csv(name)
